# %%
# !pip install gsplat>=1.0.0 viser>=0.2.0 torchmetrics>=1.0.0 lpips>=0.1.4 tyro>=0.7.0 plyfile>=1.0.0

# %%
# !git clone https://github.com/rajhodedara/SparseChron.git
# %cd SparseChron

# %%
# !python scripts/train.py --scene-dir /kaggle/input/hypernerf-interp/ --is-4d True --resume-from latest
